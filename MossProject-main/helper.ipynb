# %%
import math

# %%
def eq1(x):
    return (math.sin(0.5*x)+2)

def eq2(x):
    return (2*math.sin(0.5*(x+5))+2)

def eq3(x):
    return (0.3*math.sin(0.5*x)+2)

def eq4(x):
    return ((math.sin(0.27*x+4)) * (2.5*math.cos(1.5*x))+2.5)

# %%
def genArray(n, eq):
    ls = "(list"
    for i in range(n):
        res = str(eq(i/2))
        ls = ls + " " + res
    ls = ls + ")"
    return ls

print(genArray(500, eq4))
# Out:
# (list 3.196944288207913 2.7633219841046635 2.2822400161197343 1.7836097309397831 1.2984335446207602 0.8568773625153125 0.4863950093841436 0.210021283542833 0.04493976466980598 0.001414422049244024 0.08215145067372309 0.282131013146816 0.5889193488592162 0.9834418450014835 1.4411690036021483 1.9336415669048863 2.4302399761756313 2.9000881475612355 3.313973197437578 3.646161758023011 3.875999953549478 3.9891975582223522 3.978716493246764 3.8452084204786807 3.5969742252469805 3.249447907508385 2.824236970483513 2.347778970760867 1.8496977590763815 1.3609616127554527 0.9119577782212605 0.5306031391904091 0.2406084800566599 0.060004264158642906 1.9586898593049185e-05 0.0643840049774771 0.24909565062314298 0.5426700483456599 0.9268541639991301 1.3777612900377454 1.8673562052975987 2.365198269262268 2.840334073653282 3.263221975436477 3.607568853103242 3.8519648856172544 3.9812147113897405 3.987282202265525 3.869790111049366 3.636043526909388 3.3005756803142337 2.8842443371530786 2.41293496
# ...
